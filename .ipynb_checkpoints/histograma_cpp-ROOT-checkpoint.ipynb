// %%
%%cpp -d
//#include <iostream>
//using namespace std;

//int raan()
//{
//    return rand() % 101;
//}

// %%
#include <iostream>
#include "funcion_random.cpp"
using namespace std;

cout << "Valor ejemplo: "<<raan();
// Out:
// Valor ejemplo: 75

// %%
//%jsroot on

TCanvas canvas_2_6("c1","c1");
TF1 efunc("efunc","exp(x)");
TH1F hist_2_6_1("histogram 2.6.1","example histogram",100,0,100);
TH1F hist_2_6_2("histogram 2.6.2","example histogram",100,0,100);
for (int i=0;i<1000;i++)
{
    hist_2_6_1.Fill(raan());
    hist_2_6_2.Fill(raan());
}
c1->Divide(2,1);
c1->cd(1);hist_2_6_1.Draw();
c1->cd(2);hist_2_6_2.Draw();
canvas_2_6.Draw();

// %%
TCanvas canvas_2("c","c");
TF1 f1("f1","sin(raan()+x)/x",0.,10.);
TF1 f2("f2","sin(x)/x",0.,10.);
TF1 f3("f3","sin(raan()+x)/x",0.,10.);
c->Divide(2,2);
c->cd(1);f1.Draw();
c->cd(2);f2.Draw();
c->cd(3);f3.Draw();
canvas_2.Draw();

// %% [markdown]
// <h2>Implementación del histogram f guardado en </h2>

// %% [markdown]
// # Wii!

// %% [markdown]
// Aunque falta la prueba de fuego. Llamar la función de fuera del Notebook.

// %% [markdown]
// ## Ja! listo. Si se puede
